# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Καραβαγγέλης Αθανάσιος AM: 03117022
#
# Στοιχεία Μέλους 2:

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)

import os
path="/content/drive/MyDrive/ai-ntua/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive/

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movies_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget  ...      actor_2_name       actor_3_name
# 0           0  237000000  ...  Sigourney Weaver       Stephen Lang
# 1           1  300000000  ...   Keira Knightley  Stellan Skarsgård
# 2           2  245000000  ...       Léa Seydoux      Ralph Fiennes
# 3           3  250000000  ...       Gary Oldman      Anne Hathaway
# 4           4  260000000  ...   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
import json

#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

column_names = {'budget':'budget', 'genres': 'genre', 'plot_keywords':'keywords', 'language':'language', 'original_title':'originalTitle', 'popularity':'popularity', 'production_companies':'productionCompany', 'production_countries':'productionCountry', 'release_date':'releaseMonth', 'gross':'gross', 'duration':'duration', 'spoken_languages':'spokenLanguages', 'movie_title':'movieTitle', 'vote_average':'voteAverage', 'title_year':'titleYear', 'country':'country', 'director_name':'director', 'actor_1_name':'actor1', 'actor_2_name':'actor2', 'actor_3_name':'actor3'}

# Creates and inserts all facts for each column
def writeOne(column, curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
        movie_title = clean_text(getattr(row, 'movie_title'))
        
        attr = clean_text(str(getattr(row,column)))
        for item in attr.split("|"):
            literals.append(column_names[column]+"('"+ movie_title +"','"+ item +"')")
    literals.sort()
    for literal in literals:
        curfile.write(literal+"."+"\n")


# Same as above but for attributes in JSON format: production_companies,production_countries and spoken_languages
def writeJSONs(column, curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
        movie_title = clean_text(getattr(row, 'movie_title'))
    
        attr = ((getattr(row,column)))
        # print(clean_text(currattr.replace("'", '"')))
        if '"' in attr: continue
        attr = json.loads(clean_text(attr.replace("'", '"')))
        for company in attr:
            company = clean_text(company["name"])
            literals.append(column_names[column]+"('"+ movie_title +"','"+ company +"')")
    literals.sort()
    for literal in literals:
        curfile.write(literal+"."+"\n")

def writeRelease(curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
        movie_title = clean_text(getattr(row, 'movie_title'))

        attr = (getattr(row,"release_date"))
        if attr == "UNK": continue
        attr = attr.split("-")
        attr = attr[1]

        literals.append(column_names["release_date"]+"('"+ movie_title +"','"+ attr +"')")
    literals.sort()
    for literal in literals:
        curfile.write(literal+"."+"\n")

# %%
def writeAll():
    #This creates a file db2.pl in the current directory
    my_file = open("db2.pl", "w",encoding="utf-8")
    for column in column_names:
        if column not in ["production_companies", "production_countries","spoken_languages","release_date"]:
            writeOne(column,my_file)
        elif column != 'release_date':
            writeJSONs(column,my_file)
        else:
            writeRelease(my_file)
    my_file.close()
    
writeAll()

# %% [markdown]
# ## Ερώτημα 1β

# %%
f = open("rules.pl", 'w')
f.write(
'''
% Query 1, 2, 3

fiveGenres(X,Y):-
  genre(X,N1), genre(X,N2), N1 \= N2,
  genre(Y,N1), genre(Y,N2), X \= Y,
  genre(X,N3), N1 \= N3, N2 \= N3,
  genre(Y,N3),
  genre(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  genre(Y,N4),
  genre(X,N5), N1 \= N5, N2 \= N5,
  N3 \= N5, N4 \= N5,
  genre(Y,N5).

fourGenres(X,Y):-
  genre(X,N1), genre(X,N2), N1 \= N2,
  genre(Y,N1), genre(Y,N2), X \= Y,
  genre(X,N3), N1 \= N3, N2 \= N3,
  genre(Y,N3), genre(X,N4),
  N1 \= N4, N2 \= N4, N3 \= N4,
  genre(Y,N4).

threeGenres(X,Y):-
  genre(X,N1), genre(X,N2), genre(X,N3),
  N1 \= N2, N2 \= N3, N1 \= N3,
  genre(Y,N1), genre(Y,N2), genre(Y,N3),
  X \= Y.

twoGenres(X,Y):-
  genre(X,N1), genre(X,N2),
  N1 \= N2,
  genre(Y,N1), genre(Y,N2),
  X \= Y.

oneGenre(X,Y):-
  genre(X,N), genre(Y,N), X \= Y.

% Query 4

commonDirector(X,Y):-
  director(X,N), director(Y,N), X \= Y.

% Query 5, 6 (from 5 to one common keywords)

samePlot(X,Y):-
  keywords(X,N1), keywords(X,N2), N1 \= N2,
  keywords(Y,N1), keywords(Y,N2), X \= Y,
  keywords(X,N3), N1 \= N3, N2 \= N3,
  keywords(Y,N3),
  keywords(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  keywords(Y,N4),
  keywords(X,N5), N1 \= N5,N2 \= N5,
  N3 \= N5, N4 \= N5,
  keywords(Y,N5).

similarPlot(X,Y):-
  keywords(X,N1), keywords(X,N2),
  N1 \= N2,
  keywords(Y,N1), keywords(Y,N1),
  X \= Y.

fourKeywords(X,Y):-
  keywords(X,N1), keywords(X,N2), N1 \= N2,
  keywords(Y,N1), keywords(Y,N2), X \= Y,
  keywords(X,N3), N1 \= N3, N2 \= N3,
  keywords(Y,N3),
  keywords(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  keywords(Y,N4).

threeKeywords(X,Y):-
  keywords(X,N1), keywords(X,N2),
  N1 \= N2,
  keywords(Y,N1), keywords(Y,N1),
  X \= Y, keywords(X,N3),
  N1 \= N3, N2 \= N3,
  keywords(Y,N3).

oneKeyword(X,Y):-
  keywords(X,N), keywords(Y,N), X \= Y.

% Query 7

actor(X,N):-actor1(X,N).
actor(X,N):-actor2(X,N).
actor(X,N):-actor3(X,N).

sameActors(X,Y):-
  actor(X,N1), actor(X,N2), actor(X,N3),
  N1 \= N2, N1 \= N3, N2 \= N3,
  actor(Y,N1), actor(Y,N2), actor(Y,N3),
  X \= Y.

% Query 8 

similarActors(X,Y):-
  actor(X,N1), actor(X,N2), N1 \= N2,
  actor(Y,N1), actor(Y,N2), X \= Y.

% Query 9

oneActor(X,Y):-
  actor(X,N), actor(Y,N), X \= Y.

% Query 10

sameLanguage(X,Y):-
  language(X,N), language(Y,N), X \= Y.

% Query 11

blackAndWhite(X):-keywords(X,'black and white').

% Query 12

sameCompany(X,Y):-
  productionCompany(X,N),
  productionCompany(Y,N),
  X \= Y.

% Query 13

sameCountry(X,Y):-
  productionCountry(X,N),
  productionCountry(Y,N),
  x \= Y.

% Query 14

releasedThisDecade(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 2022,
  N > 2020.

releasedLastDecade(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 2020,
  N > 2009.

released00s(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 2010,
  N > 1999.

released90s(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 2000,
  N > 1989.

released80s(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 1990,
  N > 1979.
  
released70sAndBack(X):-
  titleYear(X,A),
  atom_number(A,N),
  N < 1980.

sameDecade(X,Y):- releasedThisDecade(X), releasedThisDecade(Y), X\=Y.
sameDecade(X,Y):- releasedLastDecade(X), releasedLastDecade(Y), X\=Y.
sameDecade(X,Y):- released00s(X), released00s(Y), X\=Y.
sameDecade(X,Y):- released90s(X), released90s(Y), X\=Y.
sameDecade(X,Y):- released80s(X), released80s(Y), X\=Y.
sameDecade(X,Y):- released70sAndBack(X), released70sAndBack(Y), X\=Y.

% Additional

winterRelease(X):-releaseMonth(X,'12').
winterRelease(X):-releaseMonth(X,'01').
winterRelease(X):-releaseMonth(X,'02').

springRelease(X):-releaseMonth(X,'03').
springRelease(X):-releaseMonth(X,'04').
springRelease(X):-releaseMonth(X,'05').

summerRelease(X):-releaseMonth(X,'06').
summerRelease(X):-releaseMonth(X,'07').
summerRelease(X):-releaseMonth(X,'08').

autumnRelease(X):-releaseMonth(X,'09').
autumnRelease(X):-releaseMonth(X,'10').
autumnRelease(X):-releaseMonth(X,'11').

sameSeason(X,Y):- autumnRelease(X),autumnRelease(Y),X\=Y.
sameSeason(X,Y):- winterRelease(X),winterRelease(Y),X\=Y.
sameSeason(X,Y):- summerRelease(X),summerRelease(Y),X\=Y.
sameSeason(X,Y):- springRelease(X),springRelease(Y),X\=Y.

sameLanguages(X,Y):-
  spokenLanguages(X,N1),
  N1 \= 'English',
  spokenLanguages(Y,N1),
  X \= Y.

highlyVoted(X):-
  voteAverage(X,A),
  atom_number(A,N),
  N > 7.

closeNum(Test):-
  Test < 7000000, Test > -7000000.

closeBudget(A1,A2):-
  atom_number(A1,N1),
  atom_number(A2,N2),
  Test is N1 - N2,
  closeNum(Test).

similarBudget(X,Y):-
  budget(X,A1), budget(Y,A2), X \= Y,
  closeBudget(A1,A2).

'''
)
f.close()

# %% [markdown]
# ##Παρουσίαση Μέρους 1

# %% [markdown]
# Επέλεξα κάποια από τα queries για να φανεί η λειτουργία τους και κάποια παρόμοια για να φανεί η διαφορα μεταξύ τους (π.χ. sameActors - similarActors)

# %%
from pyswip import Prolog
prolog = Prolog()
prolog.consult("db2.pl")        
prolog.consult("rules.pl")   

test_movies = ["Bad Boys", "Toy Story", "Eye for an Eye", "Interstellar", 
                "Harry Potter and the Half-Blood Prince","Blade Runner"]
test_queries = ["threeGenres", "oneGenre", "commonDirector","fourKeywords","samePlot",
                "sameActors","similarActors", "sameCompany","sameCountry","sameDecade"]

for movie in test_movies:
  print("\n-----------------------------------------------------------------------------------------------------------------------------\n")
  print("\033[94mMovie: "+movie)
  for query in test_queries:
      pl_query = prolog.query(query+"('"+movie+"',X)")
      print("   \033[94mQuery: "+query+"\33[0m")
      temp = [x["X"] for x in pl_query]
      s = set()
      for i in temp: 
        if i not in s: s.add(i)
      print(f"   Total matches: \033[91m{len(s)}\33[0m...including: "+str(list(s)[:10]))
# Out:
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Bad Boys
#    Query: threeGenres
#    Total matches: 291...including: ['Drive Hard', 'Kung Fu Hustle', 'Confidence', 'The Transporter Refueled', 'Duplex', 'The Proposition', 'Repo Men', 'Bad Company', 'True Romance', 'The Corruptor']
#    Query: oneGenre
#    Total matches: 3395...including: ['Star Trek Into Darkness', 'The Last Legion', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Harold & Kumar Escape from Guantanamo Bay', 'Crazy Stone', 'Dawn of the Dead']
#    Query: commonDirector
#    Total matches: 11...including: ['The Rock', 'Transformers: Dark of the Moon', 'The Island', 'Armageddon', '13 Hours: The Secret Soldiers of Benghazi', 'Pearl Harbor', 'Bad Boys II', 'Transformers: Revenge of the Fallen', 'Pain & Gain', 'Transformers: Age of Extinction']
#    Query: fourKeywords
#    Total matches: 7...including: ['Beverly Hills Cop II', 'Die Hard: With a Vengeance', 'Beverly Hills Cop', 'Cop Land', 'Beverly Hills Cop III', 'Bad Boys II', 'Con Air']
#    Query: samePlot
#    Total matches: 3...including: ['Beverly Hills Cop II', 'Beverly Hills Cop III', 'Bad Boys II']
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 0...including: []
#    Query: sameCompany
#    Total matches: 204...including: ['Kung Fu Hustle', 'Ghost Rider: Spirit of Vengeance', 'Pixels', 'Stand by Me', 'Hotel Transylvania', 'The Shallows', 'Gattaca', 'RoboCop', 'The Equalizer', 'I Dreamed of Africa']
#    Query: sameCountry
#    Total matches: 3955...including: ['Star Trek Into Darkness', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay', 'Mars Needs Moms', 'Dawn of the Dead']
#    Query: sameDecade
#    Total matches: 777...including: ['One True Thing', 'Bowfinger', 'Silent Trigger', 'The Corruptor', 'Batman & Robin', 'Eves Bayou', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Stiff Upper Lips', 'Groundhog Day']
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Toy Story
#    Query: threeGenres
#    Total matches: 110...including: ['Hotel Transylvania', 'Stuart Little', 'The Nut Job', 'TMNT', 'Cats Dont Dance', 'Hoodwinked Too! Hood VS. Evil', 'Penguins of Madagascar', 'The Croods', 'The Smurfs 2', 'Toy Story 2']
#    Query: oneGenre
#    Total matches: 1960...including: ['The Hangover', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Mars Needs Moms', 'Crazy Stone', 'Harold & Kumar Escape from Guantanamo Bay', 'Held Up', 'Jennifers Body', 'Evil Dead II', 'Barbershop']
#    Query: commonDirector
#    Total matches: 3...including: ['Cars 2', 'Toy Story 2', 'Cars']
#    Query: fourKeywords
#    Total matches: 0...including: []
#    Query: samePlot
#    Total matches: 0...including: []
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 0...including: []
#    Query: sameCompany
#    Total matches: 15...including: ['Monsters University', 'Toy Story 3', 'A Bugs Life', 'The Incredibles', 'WALL·E', 'Monsters, Inc.', 'Toy Story 2', 'Inside Out', 'Ratatouille', 'Finding Nemo']
#    Query: sameCountry
#    Total matches: 3955...including: ['Star Trek Into Darkness', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay', 'Mars Needs Moms', 'Dawn of the Dead']
#    Query: sameDecade
#    Total matches: 777...including: ['One True Thing', 'Bowfinger', 'Silent Trigger', 'The Corruptor', 'Batman & Robin', 'Eves Bayou', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Stiff Upper Lips', 'Groundhog Day']
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Eye for an Eye
#    Query: threeGenres
#    Total matches: 0...including: []
#    Query: oneGenre
#    Total matches: 3014...including: ['The Raven', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Everybodys Fine', 'Twilight Zone: The Movie', 'Barbershop', 'Winnie Mandela', 'Antarctica: A Year on Ice', 'The Good Thief', 'Ghosts of Mississippi']
#    Query: commonDirector
#    Total matches: 2...including: ['The Next Best Thing', 'Midnight Cowboy']
#    Query: fourKeywords
#    Total matches: 0...including: []
#    Query: samePlot
#    Total matches: 0...including: []
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 0...including: []
#    Query: sameCompany
#    Total matches: 281...including: ['Star Trek Into Darkness', 'April Fools Day', 'Get Rich or Die Tryin', 'Mission: Impossible III', 'The Man Who Shot Liberty Valance', 'Star Trek: First Contact', 'The Out-of-Towners', 'School of Rock', 'Darling Lili', 'How to Lose a Guy in 10 Days']
#    Query: sameCountry
#    Total matches: 3955...including: ['Star Trek Into Darkness', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay', 'Mars Needs Moms', 'Dawn of the Dead']
#    Query: sameDecade
#    Total matches: 777...including: ['One True Thing', 'Bowfinger', 'Silent Trigger', 'The Corruptor', 'Batman & Robin', 'Eves Bayou', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Stiff Upper Lips', 'Groundhog Day']
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Interstellar
#    Query: threeGenres
#    Total matches: 14...including: ['Solaris', 'The Fountain', 'Congo', 'The Host', 'The Astronaut Farmer', 'Shin Godzilla', 'Mirror Mirror', 'The Martian', 'Knowing', 'Midnight Special']
#    Query: oneGenre
#    Total matches: 3143...including: ['Star Trek Into Darkness', 'The Last Legion', 'Dredd', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Harold & Kumar Escape from Guantanamo Bay', 'Mars Needs Moms', 'Everybodys Fine', 'Twilight Zone: The Movie', 'Barbershop']
#    Query: commonDirector
#    Total matches: 7...including: ['The Dark Knight', 'The Prestige', 'Memento', 'Inception', 'Batman Begins', 'Insomnia', 'The Dark Knight Rises']
#    Query: fourKeywords
#    Total matches: 6...including: ['The Matrix Revolutions', '2001: A Space Odyssey', 'Armageddon', 'Apollo 13', 'The Martian', 'Silent Running']
#    Query: samePlot
#    Total matches: 2...including: ['Apollo 13', 'Silent Running']
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 1...including: ['The Dark Knight Rises']
#    Query: sameCompany
#    Total matches: 605...including: ['Star Trek Into Darkness', 'April Fools Day', 'The Hangover', 'Batman & Robin', 'Darling Lili', 'Warcraft', 'How to Lose a Guy in 10 Days', 'Flight', 'The Conformist', 'Twilight Zone: The Movie']
#    Query: sameCountry
#    Total matches: 4286...including: ['Star Trek Into Darkness', 'April Fools Day', 'The Last Legion', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay']
#    Query: sameDecade
#    Total matches: 1445...including: ['Star Trek Into Darkness', 'Dredd', 'The Raven', 'Mars Needs Moms', '21 & Over', 'Winnie Mandela', 'Ouija', 'Antarctica: A Year on Ice', 'Addicted', 'Free State of Jones']
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Harry Potter and the Half-Blood Prince
#    Query: threeGenres
#    Total matches: 88...including: ['Legend of the Guardians: The Owls of GaHoole', 'Aliens in the Attic', 'Harry Potter and the Goblet of Fire', 'Night at the Museum: Battle of the Smithsonian', 'The Adventurer: The Curse of the Midas Box', 'Thunder and the House of Magic', 'The Spiderwick Chronicles', 'The Croods', 'Mirror Mirror', 'Percy Jackson: Sea of Monsters']
#    Query: oneGenre
#    Total matches: 1263...including: ['Star Trek Into Darkness', 'The Last Legion', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Harold & Kumar Escape from Guantanamo Bay', 'Mars Needs Moms', 'Dawn of the Dead', 'Twilight Zone: The Movie', 'Evil Dead II', 'Antarctica: A Year on Ice']
#    Query: commonDirector
#    Total matches: 2...including: ['The Legend of Tarzan', 'Harry Potter and the Order of the Phoenix']
#    Query: fourKeywords
#    Total matches: 3...including: ['Harry Potter and the Chamber of Secrets', 'Harry Potter and the Prisoner of Azkaban', 'Harry Potter and the Order of the Phoenix']
#    Query: samePlot
#    Total matches: 0...including: []
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 5...including: ['Harry Potter and the Chamber of Secrets', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Philosophers Stone', 'Harry Potter and the Goblet of Fire', 'Harry Potter and the Prisoner of Azkaban']
#    Query: sameCompany
#    Total matches: 319...including: ['The Hangover', 'Batman & Robin', 'Twilight Zone: The Movie', 'Collateral Damage', 'Fools Gold', 'Bogus', 'City of Angels', 'Torque', 'Speed Racer', 'Malcolm X']
#    Query: sameCountry
#    Total matches: 4213...including: ['Star Trek Into Darkness', 'The Last Legion', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay']
#    Query: sameDecade
#    Total matches: 2047...including: ['The Last Legion', '51 Birch Street', 'The Hangover', 'Harold & Kumar Escape from Guantanamo Bay', 'Crazy Stone', 'Dawn of the Dead', 'Everybodys Fine', 'Jennifers Body', 'Barbershop', 'Janky Promoters']
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Movie: Blade Runner
#    Query: threeGenres
#    Total matches: 46...including: ['Dawn of the Planet of the Apes', 'Sleep Dealer', 'Vanilla Sky', 'Capricorn One', 'Knowing', 'Unbreakable', 'Yesterday Was a Lie', 'Contagion', 'Code 46', 'Dawn of the Crescent Moon']
#    Query: oneGenre
#    Total matches: 3282...including: ['Star Trek Into Darkness', 'Dredd', 'The Raven', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Everybodys Fine', 'Twilight Zone: The Movie', 'Barbershop', 'Winnie Mandela', 'Antarctica: A Year on Ice']
#    Query: commonDirector
#    Total matches: 15...including: ['A Good Year', 'Black Hawk Down', 'Gladiator', 'Body of Lies', 'Prometheus', 'American Gangster', 'Kingdom of Heaven', 'The Martian', 'Alien', 'The Counselor']
#    Query: fourKeywords
#    Total matches: 5...including: ['The Matrix', 'The Matrix Revolutions', 'Terminator Salvation', 'The Matrix Reloaded', 'Terminator 3: Rise of the Machines']
#    Query: samePlot
#    Total matches: 0...including: []
#    Query: sameActors
#    Total matches: 0...including: []
#    Query: similarActors
#    Total matches: 0...including: []
#    Query: sameCompany
#    Total matches: 318...including: ['The Hangover', 'Batman & Robin', 'Twilight Zone: The Movie', 'Collateral Damage', 'Fools Gold', 'Bogus', 'City of Angels', 'Torque', 'Speed Racer', 'Malcolm X']
#    Query: sameCountry
#    Total matches: 4242...including: ['Star Trek Into Darkness', 'The Last Legion', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Major Dundee', 'Harold & Kumar Escape from Guantanamo Bay']
#    Query: sameDecade
#    Total matches: 277...including: ['April Fools Day', 'Stand by Me', 'Tango & Cash', 'The Living Daylights', 'Caddyshack', 'Nine 1/2 Weeks', 'C.H.U.D.', 'New York Stories', 'Graduation Day', 'The Running Man']

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %% [markdown]
# ##Δημιουργία recommender.pl

# %%
f = open("recommenders.pl", "w")
f.write(
'''
precision1(X,Y):- fourKeywords(X,Y). 
precision1(X,Y):- similarActors(X,Y). 
precision1(X,Y):- blackAndWhite(X), blackAndWhite(Y), X\=Y. 
precision1(X,Y):- commonDirector(X,Y).  
precision1(X,Y):- sameCompany(X,Y).
precision1(X,Y):- sameLanguages(X,Y).
precision1(X,Y):- threeGenres(X,Y).
precision1(X,Y):- sameCountry(X,Y), highlyVoted(X), highlyVoted(Y), X\=Y.
precision1(X,Y):- sameDecade(X,Y).

precision2(X,Y):- fourKeywords(X,Y).
precision2(X,Y):- similarActors(X,Y).
precision2(X,Y):- highlyVoted(X), highlyVoted(Y), X\=Y.
precision2(X,Y):- blackAndWhite(X), blackAndWhite(Y), X\=Y.
precision2(X,Y):- commonDirector(X,Y). 
precision2(X,Y):- sameCompany(X,Y).
precision2(X,Y):- sameLanguages(X,Y).
precision2(X,Y):- threeGenres(X,Y).

precision3(X,Y):- fourKeywords(X,Y).
precision3(X,Y):- similarActors(X,Y).
precision3(X,Y):- highlyVoted(X), highlyVoted(Y), X\=Y, similarBudget(X,Y).
precision3(X,Y):- blackAndWhite(X), blackAndWhite(Y), X\=Y.
precision3(X,Y):- commonDirector(X,Y). 
precision3(X,Y):- sameCompany(X,Y).
precision3(X,Y):- sameLanguages(X,Y).
precision3(X,Y):- fourGenres(X,Y).

precision4(X,Y):- fourKeywords(X,Y).
precision4(X,Y):- sameActors(X,Y).
precision4(X,Y):- blackAndWhite(X), blackAndWhite(Y), X\=Y.
precision4(X,Y):- commonDirector(X,Y).
precision4(X,Y):- sameCompany(X,Y).
precision4(X,Y):- fiveGenres(X,Y).

precision5(X,Y):- samePlot(X,Y).
precision5(X,Y):- sameActors(X,Y).
precision5(X,Y):- blackAndWhite(X), blackAndWhite(Y), X\=Y.
precision5(X,Y):- commonDirector(X,Y).
precision5(X,Y):- fiveGenres(X,Y).
'''
)
f.close()

# %%
from pyswip import Prolog

prolog = Prolog()
prolog.consult("db2.pl")
prolog.consult("rules.pl")
prolog.consult("recommenders.pl")

# %%
def simple_recommender(movie, precision):
    s = set()
    q = prolog.query("precision"+ str(precision) +"('"+ movie +"',M)")
    for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'])
    q.close()
    answers = s
    return answers

# %%
for movie in test_movies:
  print("--------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  print("\033[94m Movie: "+ movie+"\33[0m")
  for i in range(1,6):
    print("   Precision:  "+ str(i))
    l = list(simple_recommender(movie,i))
    print("         Total matches:\033[91m   "+ str(len(l))+"\33[0m")
    print("         Including...: "+ str(l[:10]))
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Bad Boys
#    Precision:  1
#          Total matches:   1158
#          Including...: ['One True Thing', 'Bowfinger', 'Silent Trigger', 'RoboCop', 'The Corruptor', 'Batman & Robin', 'Eves Bayou', 'The Adventures of Huck Finn', 'The Equalizer', 'The Horseman on the Roof']
#    Precision:  2
#          Total matches:   487
#          Including...: ['RoboCop', 'The Corruptor', 'The Equalizer', 'Hancock', 'Groundhog Day', 'The November Man', 'A Passage to India', 'From Dusk Till Dawn', 'Ghosts of Mississippi', 'Machine Gun Preacher']
#    Precision:  3
#          Total matches:   239
#          Including...: ['Kung Fu Hustle', 'Ghost Rider: Spirit of Vengeance', 'The Island', 'Pixels', 'Hotel Transylvania', 'Stand by Me', 'The Shallows', 'Gattaca', 'Confidence', 'RoboCop']
#    Precision:  4
#          Total matches:   218
#          Including...: ['Kung Fu Hustle', 'Ghost Rider: Spirit of Vengeance', 'The Island', 'Pixels', 'Hotel Transylvania', 'Stand by Me', 'The Shallows', 'Gattaca', 'RoboCop', 'The Equalizer']
#    Precision:  5
#          Total matches:   13
#          Including...: ['Beverly Hills Cop II', 'The Rock', 'Transformers: Dark of the Moon', 'The Island', 'Transformers: Revenge of the Fallen', 'Armageddon', '13 Hours: The Secret Soldiers of Benghazi', 'Pearl Harbor', 'Beverly Hills Cop III', 'Bad Boys II']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Toy Story
#    Precision:  1
#          Total matches:   1365
#          Including...: ['Star Trek Into Darkness', 'The Hangover', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Stiff Upper Lips', 'Held Up', 'Evil Dead II', 'Ghosts of Mississippi', 'Bogus', 'The Incredibly True Adventure of Two Girls In Love']
#    Precision:  2
#          Total matches:   900
#          Including...: ['Star Trek Into Darkness', 'The Lives of Others', 'Star Wars: Clone Wars: Volume 1', 'Pans Labyrinth', 'The Hangover', 'Trash', 'Crash', 'Minority Report', 'Mad Hot Ballroom', 'Stiff Upper Lips']
#    Precision:  3
#          Total matches:   102
#          Including...: ['Gattaca', 'The Hangover', 'Se7en', 'Taken', 'The Notebook', 'Cats Dont Dance', 'District 9', 'The Help', 'L.A. Confidential', 'The Right Stuff']
#    Precision:  4
#          Total matches:   15
#          Including...: ['Monsters University', 'Toy Story 3', 'A Bugs Life', 'The Incredibles', 'WALL·E', 'Monsters, Inc.', 'Toy Story 2', 'Inside Out', 'Ratatouille', 'Finding Nemo']
#    Precision:  5
#          Total matches:   3
#          Including...: ['Cars 2', 'Toy Story 2', 'Cars']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Eye for an Eye
#    Precision:  1
#          Total matches:   1613
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'The Adventures of Huck Finn', 'The Horseman on the Roof', 'Stiff Upper Lips', 'Major Dundee', 'Held Up', 'Jennifers Body', 'Twilight Zone: The Movie', 'Just Like Heaven']
#    Precision:  2
#          Total matches:   998
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'Crazy/Beautiful', 'Blackthorn', 'Kites', 'Pans Labyrinth', 'Tinker Tailor Soldier Spy', 'Darling Lili', 'The Adventures of Huck Finn', 'Crash']
#    Precision:  3
#          Total matches:   998
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'Crazy/Beautiful', 'Blackthorn', 'Kites', 'Pans Labyrinth', 'Tinker Tailor Soldier Spy', 'Darling Lili', 'The Adventures of Huck Finn', 'Crash']
#    Precision:  4
#          Total matches:   282
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'Get Rich or Die Tryin', 'Mission: Impossible III', 'The Man Who Shot Liberty Valance', 'Star Trek: First Contact', 'The Out-of-Towners', 'School of Rock', 'Darling Lili', 'How to Lose a Guy in 10 Days']
#    Precision:  5
#          Total matches:   2
#          Including...: ['The Next Best Thing', 'Midnight Cowboy']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Interstellar
#    Precision:  1
#          Total matches:   2367
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'Dredd', 'The Hangover', 'The Raven', 'Stiff Upper Lips', 'Mars Needs Moms', 'Twilight Zone: The Movie', 'Evil Dead II', '21 & Over']
#    Precision:  2
#          Total matches:   1301
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'The Hangover', 'Stiff Upper Lips', 'Twilight Zone: The Movie', 'Evil Dead II', 'Antarctica: A Year on Ice', 'Fools Gold', 'Bogus', 'St. Vincent']
#    Precision:  3
#          Total matches:   619
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'The Hangover', 'Batman & Robin', 'Darling Lili', 'Warcraft', 'How to Lose a Guy in 10 Days', 'Flight', 'The Conformist', 'Twilight Zone: The Movie']
#    Precision:  4
#          Total matches:   612
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'The Hangover', 'Batman & Robin', 'Darling Lili', 'Warcraft', 'How to Lose a Guy in 10 Days', 'Flight', 'The Conformist', 'Twilight Zone: The Movie']
#    Precision:  5
#          Total matches:   9
#          Including...: ['The Dark Knight', 'Apollo 13', 'The Prestige', 'Memento', 'Inception', 'Batman Begins', 'Insomnia', 'The Dark Knight Rises', 'Silent Running']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Harry Potter and the Half-Blood Prince
#    Precision:  1
#          Total matches:   2675
#          Including...: ['Star Trek Into Darkness', 'The Last Legion', '51 Birch Street', 'The Hangover', 'Stiff Upper Lips', 'Harold & Kumar Escape from Guantanamo Bay', 'Crazy Stone', 'Dawn of the Dead', 'Everybodys Fine', 'Twilight Zone: The Movie']
#    Precision:  2
#          Total matches:   1113
#          Including...: ['Star Trek Into Darkness', 'The Lives of Others', 'Star Wars: Clone Wars: Volume 1', 'Aliens in the Attic', 'Pans Labyrinth', 'The Hangover', 'Batman & Robin', 'Trash', 'Crash', 'Minority Report']
#    Precision:  3
#          Total matches:   324
#          Including...: ['The Hangover', 'Batman & Robin', 'Twilight Zone: The Movie', 'Collateral Damage', 'Fools Gold', 'Bogus', 'City of Angels', 'Torque', 'Speed Racer', 'Malcolm X']
#    Precision:  4
#          Total matches:   320
#          Including...: ['The Hangover', 'Batman & Robin', 'Twilight Zone: The Movie', 'Collateral Damage', 'Fools Gold', 'Bogus', 'City of Angels', 'Torque', 'Speed Racer', 'Malcolm X']
#    Precision:  5
#          Total matches:   2
#          Including...: ['The Legend of Tarzan', 'Harry Potter and the Order of the Phoenix']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Movie: Blade Runner
#    Precision:  1
#          Total matches:   1468
#          Including...: ['Star Trek Into Darkness', 'April Fools Day', 'The Hangover', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Twilight Zone: The Movie', 'Evil Dead II', 'Fools Gold', 'Bogus', 'Free State of Jones']
#    Precision:  2
#          Total matches:   1382
#          Including...: ['Star Trek Into Darkness', 'The Hangover', 'The Adventures of Huck Finn', 'Stiff Upper Lips', 'Twilight Zone: The Movie', 'Evil Dead II', 'Antarctica: A Year on Ice', 'Fools Gold', 'Bogus', 'Free State of Jones']
#    Precision:  3
#          Total matches:   783
#          Including...: ['The Lives of Others', 'Tinker Tailor Soldier Spy', 'The Hangover', 'Batman & Robin', 'Darling Lili', 'The Adventures of Huck Finn', 'The Corruptor', 'Hancock', 'Twilight Zone: The Movie', 'District 9']
#    Precision:  4
#          Total matches:   332
#          Including...: ['The Hangover', 'Batman & Robin', 'Twilight Zone: The Movie', 'Collateral Damage', 'Fools Gold', 'Bogus', 'City of Angels', 'Torque', 'Speed Racer', 'Malcolm X']
#    Precision:  5
#          Total matches:   15
#          Including...: ['A Good Year', 'Black Hawk Down', 'Gladiator', 'Body of Lies', 'Prometheus', 'American Gangster', 'Kingdom of Heaven', 'The Martian', 'Alien', 'The Counselor']

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
#Some things from part 1
import pandas as pd
import json
from pyswip import Prolog

prolog = Prolog()
prolog.consult("db2.pl")
prolog.consult("rules.pl")
prolog.consult("recommenders.pl")

def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {1:0.0001, 2: 0.005, 3: 4, 4: 7, 5: 11} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, start=0, end = -1, movie_score = {}):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if end == -1:
        end = len(ratings)

    ratings = ratings.iloc[range(start, end)]

    for row in tqdm(ratings.itertuples(index=True, name='Pandas'),ncols='480px'):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        # simple recommender for all precisions 1-5
        similar_movies = {i:simple_recommender(movie,i) for i in range(5,0,-1)}
        for precision in range(5,0,-1):
          for similar_movie in similar_movies[precision]:
              if similar_movie not in movie_score:
                  movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[precision]
              else:
                  movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[precision] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > -0.5)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Οι παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %% [markdown]
# ### Για 4 ratings (20 πειράματα)

# %%
metrics = []
for i in range (20):
    X = random.choice([j for j in range(97)])
    movie_score = train_recommender(train_ratings, rating_weights, score_weights,X,X+4)
    real, pred = predict_example(test_ratings, movie_score)
    print(get_metrics(real, pred))
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# precision: 0.5
# recall: 0.8333333333333334
# f1: 0.625

# %% [markdown]
# ### Για 10 ratings (10 πειράματα)

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights,i,i+10)
    real, pred = predict_example(test_ratings, movie_score)
    print(get_metrics(real, pred))
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.4953271028037383, 'recall': 0.7361111111111112, 'f1': 0.5921787709497207}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49523809523809526, 'recall': 0.7222222222222222, 'f1': 0.5875706214689266}
# 0it [00:00, ?it/s]
# {'precision': 0.49523809523809526, 'recall': 0.7222222222222222, 'f1': 0.5875706214689266}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# 0it [00:00, ?it/s]
# {'precision': 0.49056603773584906, 'recall': 0.7222222222222222, 'f1': 0.5842696629213483}
# precision: 0.4919765557430873
# recall: 0.7236111111111111
# f1: 0.5857207654337012

# %% [markdown]
# ### Για 30 ratings (8 πειράματα)

# %%
metrics = []
for i in range (8):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights,i*10,(i+3)*10)
    real, pred = predict_example(test_ratings, movie_score)
    print(get_metrics(real, pred))
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5161290322580645, 'recall': 0.8888888888888888, 'f1': 0.6530612244897959}
# 0it [00:00, ?it/s]
# {'precision': 0.52, 'recall': 0.9027777777777778, 'f1': 0.6598984771573604}
# 0it [00:00, ?it/s]
# {'precision': 0.5081967213114754, 'recall': 0.8611111111111112, 'f1': 0.6391752577319588}
# 0it [00:00, ?it/s]
# {'precision': 0.5081967213114754, 'recall': 0.8611111111111112, 'f1': 0.6391752577319588}
# 0it [00:00, ?it/s]
# {'precision': 0.5161290322580645, 'recall': 0.8888888888888888, 'f1': 0.6530612244897959}
# precision: 0.508581438392385
# recall: 0.8628472222222223
# f1: 0.6399214302001087

# %% [markdown]
# ### Για 50 ratings (6 πειράματα)

# %%
metrics = []
for i in range (6):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights,i*10,(i+5)*10)
    real, pred = predict_example(test_ratings, movie_score)
    print(get_metrics(real, pred))
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.4915254237288136, 'recall': 0.8055555555555556, 'f1': 0.6105263157894737}
# 0it [00:00, ?it/s]
# {'precision': 0.4915254237288136, 'recall': 0.8055555555555556, 'f1': 0.6105263157894737}
# 0it [00:00, ?it/s]
# {'precision': 0.4915254237288136, 'recall': 0.8055555555555556, 'f1': 0.6105263157894737}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8472222222222222, 'f1': 0.6288659793814433}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# precision: 0.4957627118644068
# recall: 0.8217592592592592
# f1: 0.618407487791644

# %% [markdown]
# ### Για 100 ratings

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights,0,100)
real, pred = predict_example(test_ratings, movie_score)
print(get_metrics(real, pred))
metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.5, 'recall': 0.8333333333333334, 'f1': 0.625}
# precision: 0.4963680387409201
# recall: 0.8234126984126984
# f1: 0.6193492752499806

# %% [markdown]
# ## Συμπεράσματα

# %% [markdown]
# Δοκίμασα ένα αρκετά μεγάλο πλήθος συνδιασμών τόσο στα score_weights και στο όριο στο οποίο μία ταινία γίνεται recommend αλλά και στους κανόνες που ορίζω το precision.
#
# Ωστόσο οι μετρικές δεν παρουσίασαν μεγάλη διαφορά, το συμπέρασμα είναι ότι το σύστημα προτάσεων που υλοποίησα προτείνει παραπάνω ταίνιες από το ιδανικό.
#
# Φυσικά, για κάποιον άλλο χρήστη που βαθμολογεί με διαφορετικό τρόπο είτε υψήλοτερα, είτε χαμηλότερα τις ταινίες , οι μετρικές μπορεί να έδιναν διαφορετικό αποτέλεσμα.
#
# Παρατηρώ πως το σύστημα αποδίδει ελαφρώς καλύτερα στις δοκιμές για 4 ratings αλλα και σε αυτές των 30. Αυτό δείχνει πως λειτουργεί ελαφρώς καλύτερα για νέους χρήστες που έχουν κάνει λίγα ratings αλλά και για πιο παλιούς με 30 ratings. Με μικρή διαφορά βέβαια από τα πειράματα με άλλο αριθμό ratings.
